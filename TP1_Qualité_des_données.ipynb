# %%
#Imports librairies de base
import numpy as np
import pandas as pd



#Affichage de Graphes
from IPython.display import Markdown, display, HTML

# %%
csv = pd.read_csv('Climat-SI.csv')
data = csv.loc[0:,"janvier":"décembre"]
csv.sample(10)
# Out:
#    jour  janvier  février  mars  avril  mai  juin  juillet  août  septembre  \
# 28  J29       -5      NaN     5   14.0   16  21.0       22    17        7.0
# 0    J1       -5     -7.0    -7    2.0   12  17.0       20    20       16.0
# 7    J8       -8    -11.0     1    6.0    7  15.0       17    17       11.0
# 19  J20       -8      2.0    -1   11.0   15  19.0       17    21       11.0
# 20  J21       -9      3.0     0   12.0   15  20.0       18    21       12.0
# 23  J24      -17     -4.0     3    8.0   16  22.0       24    18       11.0
# 13  J14      -10      1.0     5   10.0   10  14.0       13    15        9.0
# 6    J7       -6      5.0     2    4.0    8  17.0       16    16       12.0
# 3    J4       -3     -6.0    -3    6.0   16  14.0       18    18       13.0
# 29  J30       -6      NaN     3   16.0   17  17.0       23    18        6.0
#
#     octobre  novembre  décembre
# 28        4      -6.0        -6
# 0         6       0.0        -6
# 7         5       5.0        -4
# 19        6       1.0        -8
# 20        7       0.0        -3
# 23        6       3.0        -9
# 13        3      -8.0        -7
# 6         4       4.0        -8
# 3         4       3.0        -9
# 29        2      -4.0        -7

# %%
round(data.mean()) #moyenne par mois
# Out:
# janvier      -9.0
# février      -5.0
# mars          1.0
# avril         8.0
# mai          13.0
# juin         17.0
# juillet      18.0
# août         18.0
# septembre    10.0
# octobre       4.0
# novembre     -0.0
# décembre     -7.0
# dtype: float64

# %%
round(data.mean().mean()) #moyenne des mois de l'année
# Out:
# 6.0

# %%
round(data.std()) # ecart type par mois
# Out:
# janvier      4.0
# février      5.0
# mars         4.0
# avril        3.0
# mai          4.0
# juin         3.0
# juillet      4.0
# août         3.0
# septembre    2.0
# octobre      2.0
# novembre     4.0
# décembre     2.0
# dtype: float64

# %%
data.min()
# Out:
# janvier     -23.0
# février     -12.0
# mars         -8.0
# avril         2.0
# mai           5.0
# juin         11.0
# juillet      13.0
# août         14.0
# septembre     6.0
# octobre       1.0
# novembre     -8.0
# décembre    -11.0
# dtype: float64

# %%
data.min().min()
# Out:
# -23.0

# %%
data.max()
# Out:
# janvier      -3.0
# février       5.0
# mars          7.0
# avril        16.0
# mai          18.0
# juin         22.0
# juillet      26.0
# août         26.0
# septembre    16.0
# octobre       7.0
# novembre      5.0
# décembre     -3.0
# dtype: float64

# %%
data.max().max()
# Out:
# 26.0

# %%
import matplotlib.pyplot as plt
#!pip install mplcursors  # from PyPI
#import mplcursors
#data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
months = list(data.loc[:0,])
print(months)
fig, axs = plt.subplots(1, 12, figsize=(24, 6), sharey=True)

fig.suptitle('Months Tmp evolution')
for i in range(len(months)):
  values = list(data.loc[0:,months[i]])
  values = [x for x in values if str(x) != 'nan']
  names = range(0,len(values))
  print(names)
  
  print(values)
  
  axs[i].plot(names, values)
# Out:
# ['janvier', 'février', 'mars', 'avril', 'mai', 'juin', 'juillet', 'août', 'septembre', 'octobre', 'novembre', 'décembre']
# range(0, 31)
# [-5, -6, -5, -3, -6, -11, -6, -8, -11, -8, -8, -8, -8, -10, -10, -9, -6, -6, -4, -8, -9, -14, -15, -17, -19, -23, -8, -9, -5, -6, -7]
# range(0, 28)
# [-7.0, -6.0, -5.0, -6.0, -8.0, -9.0, 5.0, -11.0, -12.0, -9.0, -6.0, -5.0, -4.0, 1.0, 3.0, -9.0, -6.0, -6.0, -4.0, 2.0, 3.0, 1.0, -3.0, -4.0, -6.0, -8.0, -8.0, -11.0]
# range(0, 31)
# [-7, -8, -5, -3, -2, 1, 2, 1, 1, 2, 1, 3, 5, 5, 7, 3, 2, -1, -2, -1, 0, 1, 2, 3, 4, 3, 4, 5, 5, 3, 3]
# range(0, 30)
# [2.0, 3.0, 4.0, 6.0, 4.0, 5.0, 4.0, 6.0, 7.0, 7.0, 8.0, 8.0, 9.0, 10.0, 8.0, 8.0, 9.0, 11.0, 10.0, 11.0, 12.0, 9.0, 7.0, 8.0, 8.0, 6.0, 9.0, 11.0, 14.0, 16.0]
# range(0, 31)
# [12, 14, 15, 16, 13, 12, 8, 7, 6, 5, 5, 6, 8, 10, 12, 13, 14, 13, 15, 15, 15, 18, 18, 16, 15, 16, 16, 17, 16, 17, 17]
# range(0, 30)
# [17.0, 16.0, 17.0, 14.0, 15.0, 17.0, 17.0, 15.0, 14.0, 15.0, 14.0, 13.0, 11.0, 14.0, 15.0, 15.0, 15.0, 17.0, 16.0, 19.0, 20.0, 19.0, 20.0, 22.0, 22.0, 21.0, 22.0, 21.0, 21.0, 17.0]
# range(0, 31)
# [20, 20, 17, 18, 17, 17, 16, 17, 17, 15, 15, 16, 16, 13, 14, 14, 15, 15, 15, 17, 18, 19, 21, 24, 23, 26, 26, 21, 22, 23, 21]
# range(0, 31)
# [20, 19, 19, 18, 17, 18, 16, 17, 15, 14, 14, 15, 15, 15, 17, 18, 19, 21, 24, 21, 21, 26, 17, 18, 17, 17, 16, 17, 17, 18, 17]
# range(0, 30)
# [16.0, 14.0, 15.0, 13.0, 12.0, 10.0, 12.0, 11.0, 11.0, 12.0, 10.0, 10.0, 9.0, 9.0, 10.0, 11.0, 10.0, 10.0, 9.0, 11.0, 12.0, 12.0, 10.0, 11.0, 10.0, 9.0, 6.0, 7.0, 7.0, 6.0]
# range(0, 31)
# [6, 2, 3, 4, 3, 2, 4, 5, 3, 4, 2, 1, 3, 3, 3, 1, 4, 6, 6, 6, 7, 7, 6, 6, 6, 4, 3, 3, 4, 2, 1]
# range(0, 30)
# [0.0, 1.0, 2.0, 3.0, 4.0, 3.0, 4.0, 5.0, 5.0, -1.0, -2.0, -1.0, -7.0, -8.0, -5.0, -3.0, -2.0, 1.0, 2.0, 1.0, 0.0, 0.0, 1.0, 3.0, 5.0, -2.0, -3.0, -6.0, -6.0, -4.0]
# range(0, 31)
# [-6, -4, -8, -9, -9, -9, -8, -4, -3, -8, -9, -5, -6, -7, -11, -6, -8, -11, -8, -8, -3, -6, -8, -9, -5, -6, -7, -8, -6, -7, -5]

# %%
import matplotlib.pyplot as plt

#data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
months = list(data.loc[:0,])
print(months)
fig, axs = plt.subplots(1, 1, figsize=(24, 6), sharey=False,squeeze=False)

fig.suptitle('Year Tmp evolution')

totalyear = []
for i in range(len(months)):
  values = list(data.loc[0:,months[i]])
  #names = range(0,len(values))
  #print(names)

  #print(values)
  totalyear += values
  
 

totalyear = [x for x in totalyear if str(x) != 'nan']

lines = axs[0,0].plot(range(0, len(totalyear)), totalyear )
print(totalyear[0:10])
print(len(totalyear ))  
#mplcursors.cursor(lines) # or just mplcursors.cursor()
plt.show()
# Out:
# ['janvier', 'février', 'mars', 'avril', 'mai', 'juin', 'juillet', 'août', 'septembre', 'octobre', 'novembre', 'décembre']
# [-5, -6, -5, -3, -6, -11, -6, -8, -11, -8]
# 365

# %%
import matplotlib.pyplot as plt

#data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
months = list(data.loc[:0,])
fig, axs = plt.subplots(1, 1, figsize=(24, 6), sharey=False,squeeze=False)

fig.suptitle('Year Tmp evolution')

totalyear = []
for i in range(len(months)):
  values = list(data.loc[0:,months[i]])
  #names = range(0,len(values))
  #print(names)

  #print(values)
  totalyear += values
  
 

totalyear = [x for x in totalyear if str(x) != 'nan']
selecteddayinyear = 75
axs[0,0].plot(range(selecteddayinyear-15,selecteddayinyear+15), totalyear[selecteddayinyear-15:selecteddayinyear+15] )


plt.show()

# %%
csverr = pd.read_csv('Climat-SI-erreur.csv')
#csverr['février'].replace(np.nan, 230)
#csverr['février'] = pd.to_numeric(csverr.février, errors='coerce').interpolate()
#csverr['février'] = pd.to_numeric(csverr.février, errors='coerce').fillna(230)
#csverr['mars'] = pd.to_numeric(csverr.mars, errors='coerce').interpolate()
#csverr['juin'] = pd.to_numeric(csverr.juin, errors='coerce').fillna(np.nan)
csverr
# Out:
#    jour  janvier  février    mars  avril  mai juin juillet  août  septembre  \
# 0    J1       -5     -7.0      -7    2.0   12   17      20    20       16.0
# 1    J2       -6     -6.0      -8    3.0   14   16      20    19       14.0
# 2    J3       -5     -5.0      -5    4.0   15   17      17    19       15.0
# 3    J4       -3     -6.0      -3    6.0   16   14      18    18       13.0
# 4    J5       -6     -8.0      -2    4.0   13   15      17    17       12.0
# 5    J6      -11     -9.0       1    5.0   12   17      17    18       10.0
# 6    J7       -6      5.0       2    4.0    8   17      16    16       12.0
# 7    J8       -8    -11.0       1    6.0    7   15      17    17       11.0
# 8    J9      -11    -12.0       1    7.0    6   14      17    15       11.0
# 9   J10       -8     -9.0       2    7.0    5  Sun      15    14       12.0
# 10  J11       -8     -6.0       1    8.0    5   14      15    14       10.0
# 11  J12       -8     -5.0       3    8.0    6   13      16    15       10.0
# 12  J13       -8     -4.0       5    9.0    8   11      16    15        9.0
# 13  J14      -10      1.0       5   10.0   10   14      13    15        9.0
# 14  J15      -10      3.0       7    8.0   12   15      14    48       10.0
# 15  J16       -9     -9.0  0xFFFF    8.0   13   15      -6    18       11.0
# 16  J17       -6     -6.0       2    9.0   14   15      15    19       10.0
# 17  J18       -6     -6.0      -1   11.0   13   17      15    21       10.0
# 18  J19       -4     -4.0      -2   10.0   15   16      15    24        9.0
# 19  J20       -8      2.0      -1   11.0   15   19      17    21       11.0
# 20  J21       -9      3.0       0   12.0   15   20      18    21       12.0
# 21  J22      -14      1.0       1    9.0   18   19      19    26       12.0
# 22  J23      -15     -3.0       2    7.0   18   20  0xFFFF    17       10.0
# 23  J24      -17     -4.0       3    8.0   16   22      24    18       11.0
# 24  J25      -19     -6.0       4    8.0   15   22      23    17       10.0
# 25  J26      -23     -8.0       3    6.0   16   21      26    17        9.0
# 26  J27       -8     -8.0       4    9.0   16   22      26    16        6.0
# 27  J28       -9    -11.0       5   11.0   17   21      21    17        7.0
# 28  J29       -5      NaN       5   14.0   16   21      22    17        7.0
# 29  J30       -6      NaN       3   16.0   17   17      23    18        6.0
# 30  J31       -7      NaN       3    NaN   17  NaN      21    17        NaN
#
#    octobre  novembre  décembre
# 0        6       0.0        -6
# 1        2       1.0        -4
# 2        3       2.0        -8
# 3        4       3.0        -9
# 4        3       4.0        -9
# 5        2       3.0        -9
# 6        4       4.0        -8
# 7   0xFFFF       5.0        -4
# 8        3       5.0        -3
# 9        4      -1.0        -8
# 10       2      -2.0        -9
# 11       1      -1.0        -5
# 12       3      -7.0        -6
# 13       3      -8.0        -7
# 14       3      -5.0       -11
# 15       1      -3.0        -6
# 16       4      -2.0        -8
# 17       6       1.0       -11
# 18       6       2.0        -8
# 19       6       1.0        -8
# 20       7       0.0       -33
# 21       7       0.0        -6
# 22       6       1.0        -8
# 23       6       3.0        -9
# 24       6       5.0        -5
# 25       4      -2.0        -6
# 26       3      -3.0        -7
# 27       3      -6.0        -8
# 28       4      -6.0        -6
# 29       2      -4.0        -7
# 30       1       NaN        -5

# %%
import math
import statistics 
data = csverr.loc[0:,"janvier":"décembre"]
months = list(data.loc[:0,])
print(months)

fig, axs = plt.subplots(1, 1, figsize=(24, 6), sharey=False,squeeze=False)

fig.suptitle('Year Tmp evolution')
totalyearerr = []
for i in range(len(months)):
  values = list(data.loc[0:,months[i]])
  totalyearerr += values
  #currentmonth = months[i]
  #print(csverr[currentmonth])
  #csverr[currentmonth].replace(np.nan, 230)
  #print(csverr[currentmonth])

  #csverr[currentmonth] = pd.to_numeric(csverr[currentmonth], errors='coerce').interpolate()
proxdays = []
for j in range(len(totalyearerr)):
  if (j > 0 and j < 365):
    if(math.isnan(totalyearerr[j])):
      totalyearerr[j] = statistics.mean([totalyearerr[j-1], totalyearerr[j+1]])
    elif(totalyearerr[j] < (totalyearerr[j-1]-15) or totalyearerr[j] > (totalyearerr[j-1]+15) ):
      totalyearerr[j] = statistics.mean([totalyearerr[j-1], totalyearerr[j+1]])
    
    

#csverr
lines = axs[0,0].plot(range(0, len(totalyearerr)), totalyearerr )
print(totalyearerr[0:10])
totalyearerr
print(len(totalyearerr ))
plt.show()
print(totalyearerr)
# Out:
# ['janvier', 'février', 'mars', 'avril', 'mai', 'juin', 'juillet', 'août', 'septembre', 'octobre', 'novembre', 'décembre']
# [-5, -6, -5, -3, -6, -11, -6, -8, -11, -8]
# 372
